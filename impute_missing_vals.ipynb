# %%
import pandas as pd
import numpy as np

# %%
impute_df = pd.read_csv('impute_df.csv')

# %%
impute_df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'date', 'store_nbr', 'family', 'sales',
#        'onpromotion', 'data_id', 'dcoilwtico', 'city', 'state', 'type',
#        'cluster', 'transactions', 'month', 'day', 'year', 'was_holiday'],
#       dtype='object')

# %%
# seperate target features from df to impute oil price

test = impute_df[impute_df['dcoilwtico'].isna()]
feature_cols = ['id','city', 'state','dcoilwtico', 'type','store_nbr', 'family',
                 'cluster','month', 'day', 'year']
train = impute_df[~impute_df['dcoilwtico'].isna()]
train = train[feature_cols]
test = test[feature_cols]

# %%
# seperate targets and features to impute oil price

X_train = train.drop(['id','dcoilwtico'], axis = 1)
y_train = train['dcoilwtico']

X_test = test.drop(['id','dcoilwtico'], axis = 1)

# %%
X_test
# Out:
#           city      state type  store_nbr                      family  \
# 0        Quito  Pichincha    D          1                  AUTOMOTIVE
# 1        Quito  Pichincha    D          1                   BABY CARE
# 2        Quito  Pichincha    D          1                      BEAUTY
# 3        Quito  Pichincha    D          1                   BEVERAGES
# 4        Quito  Pichincha    D          1                       BOOKS
# ...        ...        ...  ...        ...                         ...
# 3022267  Quito  Pichincha    B          9                     POULTRY
# 3022268  Quito  Pichincha    B          9              PREPARED FOODS
# 3022269  Quito  Pichincha    B          9                     PRODUCE
# 3022270  Quito  Pichincha    B          9  SCHOOL AND OFFICE SUPPLIES
# 3022271  Quito  Pichincha    B          9                     SEAFOOD
#
#          cluster  month  day  year
# 0             13      1    1  2013
# 1             13      1    1  2013
# 2             13      1    1  2013
# 3             13      1    1  2013
# 4             13      1    1  2013
# ...          ...    ...  ...   ...
# 3022267        6      8   27  2017
# 3022268        6      8   27  2017
# 3022269        6      8   27  2017
# 3022270        6      8   27  2017
# 3022271        6      8   27  2017
#
# [935550 rows x 9 columns]

# %%
categorical_columns = ['city','state','type','family']

for col in categorical_columns:
    X_train[col] = X_train[col].astype('category')
    
for col in categorical_columns:
    X_test[col] = X_test[col].astype('category')

# %%
# use lightlgbm to predict oil prices for missing values
import lightgbm as lgb


cat_features = ['city','state','type','family']

model_data = lgb.Dataset(X_train, label=y_train, categorical_feature = cat_features)


# Set hyperparameters for the model
params = {
    'objective': 'regression',
    'metric': 'mse',
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}

# Train the model
num_round = 100
lgb_model = lgb.train(params, model_data, num_round)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016180 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 204
# [LightGBM] [Info] Number of data points in the train set: 2093850, number of used features: 9
# [LightGBM] [Info] Start training from score 67.714366

# %%
# make preds with lgb
oil_values = lgb_model.predict(X_test)

# %%
oil_vals_ser = pd.Series(oil_values)

oil_vals_ser
# Out:
# 0         95.162954
# 1         95.162954
# 2         95.162954
# 3         95.162954
# 4         95.162954
#             ...
# 935545    48.637495
# 935546    48.637495
# 935547    48.637495
# 935548    48.637495
# 935549    48.637495
# Length: 935550, dtype: float64

# %%
test['dcoilwtico'] = oil_vals_ser.values

# %%
test
# Out:
#               id   city      state  dcoilwtico type  store_nbr  \
# 0              0  Quito  Pichincha   95.162954    D          1
# 1              1  Quito  Pichincha   95.162954    D          1
# 2              2  Quito  Pichincha   95.162954    D          1
# 3              3  Quito  Pichincha   95.162954    D          1
# 4              4  Quito  Pichincha   95.162954    D          1
# ...          ...    ...        ...         ...  ...        ...
# 3022267  3022267  Quito  Pichincha   48.637495    B          9
# 3022268  3022268  Quito  Pichincha   48.637495    B          9
# 3022269  3022269  Quito  Pichincha   48.637495    B          9
# 3022270  3022270  Quito  Pichincha   48.637495    B          9
# 3022271  3022271  Quito  Pichincha   48.637495    B          9
#
#                              family  cluster  month  day  year
# 0                        AUTOMOTIVE       13      1    1  2013
# 1                         BABY CARE       13      1    1  2013
# 2                            BEAUTY       13      1    1  2013
# 3                         BEVERAGES       13      1    1  2013
# 4                             BOOKS       13      1    1  2013
# ...                             ...      ...    ...  ...   ...
# 3022267                     POULTRY        6      8   27  2017
# 3022268              PREPARED FOODS        6      8   27  2017
# 3022269                     PRODUCE        6      8   27  2017
# 3022270  SCHOOL AND OFFICE SUPPLIES        6      8   27  2017
# 3022271                     SEAFOOD        6      8   27  2017
#
# [935550 rows x 11 columns]

# %%
impute_df
# Out:
#          Unnamed: 0       id        date  store_nbr  \
# 0                 0        0  2013-01-01          1
# 1                 1        1  2013-01-01          1
# 2                 2        2  2013-01-01          1
# 3                 3        3  2013-01-01          1
# 4                 4        4  2013-01-01          1
# ...             ...      ...         ...        ...
# 3029395     3029395  3029395  2017-08-31          9
# 3029396     3029396  3029396  2017-08-31          9
# 3029397     3029397  3029397  2017-08-31          9
# 3029398     3029398  3029398  2017-08-31          9
# 3029399     3029399  3029399  2017-08-31          9
#
#                              family  sales  onpromotion data_id  dcoilwtico  \
# 0                        AUTOMOTIVE    0.0            0     df1         NaN
# 1                         BABY CARE    0.0            0     df1         NaN
# 2                            BEAUTY    0.0            0     df1         NaN
# 3                         BEVERAGES    0.0            0     df1         NaN
# 4                             BOOKS    0.0            0     df1         NaN
# ...                             ...    ...          ...     ...         ...
# 3029395                     POULTRY    NaN            1     df2       47.26
# 3029396              PREPARED FOODS    NaN            0     df2       47.26
# 3029397                     PRODUCE    NaN            1     df2       47.26
# 3029398  SCHOOL AND OFFICE SUPPLIES    NaN            9     df2       47.26
# 3029399                     SEAFOOD    NaN            0     df2       47.26
#
#           city      state type  cluster  transactions  month  day  year  \
# 0        Quito  Pichincha    D       13           NaN      1    1  2013
# 1        Quito  Pichincha    D       13           NaN      1    1  2013
# 2        Quito  Pichincha    D       13           NaN      1    1  2013
# 3        Quito  Pichincha    D       13           NaN      1    1  2013
# 4        Quito  Pichincha    D       13           NaN      1    1  2013
# ...        ...        ...  ...      ...           ...    ...  ...   ...
# 3029395  Quito  Pichincha    B        6           NaN      8   31  2017
# 3029396  Quito  Pichincha    B        6           NaN      8   31  2017
# 3029397  Quito  Pichincha    B        6           NaN      8   31  2017
# 3029398  Quito  Pichincha    B        6           NaN      8   31  2017
# 3029399  Quito  Pichincha    B        6           NaN      8   31  2017
#
#          was_holiday
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# 3029395        False
# 3029396        False
# 3029397        False
# 3029398        False
# 3029399        False
#
# [3029400 rows x 18 columns]

# %%
impute_df.update(test)

# %%
impute_df.isna().sum()
# Out:
# Unnamed: 0           0
# id                   0
# date                 0
# store_nbr            0
# family               0
# sales            28512
# onpromotion          0
# data_id              0
# dcoilwtico           0
# city                 0
# state                0
# type                 0
# cluster              0
# transactions    274296
# month                0
# day                  0
# year                 0
# was_holiday          0
# dtype: int64

# %%
impute_df
# Out:
#          Unnamed: 0       id        date  store_nbr  \
# 0                 0        0  2013-01-01          1
# 1                 1        1  2013-01-01          1
# 2                 2        2  2013-01-01          1
# 3                 3        3  2013-01-01          1
# 4                 4        4  2013-01-01          1
# ...             ...      ...         ...        ...
# 3029395     3029395  3029395  2017-08-31          9
# 3029396     3029396  3029396  2017-08-31          9
# 3029397     3029397  3029397  2017-08-31          9
# 3029398     3029398  3029398  2017-08-31          9
# 3029399     3029399  3029399  2017-08-31          9
#
#                              family  sales  onpromotion data_id  dcoilwtico  \
# 0                        AUTOMOTIVE    0.0            0     df1   95.162954
# 1                         BABY CARE    0.0            0     df1   95.162954
# 2                            BEAUTY    0.0            0     df1   95.162954
# 3                         BEVERAGES    0.0            0     df1   95.162954
# 4                             BOOKS    0.0            0     df1   95.162954
# ...                             ...    ...          ...     ...         ...
# 3029395                     POULTRY    NaN            1     df2   47.260000
# 3029396              PREPARED FOODS    NaN            0     df2   47.260000
# 3029397                     PRODUCE    NaN            1     df2   47.260000
# 3029398  SCHOOL AND OFFICE SUPPLIES    NaN            9     df2   47.260000
# 3029399                     SEAFOOD    NaN            0     df2   47.260000
#
#           city      state type  cluster  transactions  month  day  year  \
# 0        Quito  Pichincha    D       13           NaN      1    1  2013
# 1        Quito  Pichincha    D       13           NaN      1    1  2013
# 2        Quito  Pichincha    D       13           NaN      1    1  2013
# 3        Quito  Pichincha    D       13           NaN      1    1  2013
# 4        Quito  Pichincha    D       13           NaN      1    1  2013
# ...        ...        ...  ...      ...           ...    ...  ...   ...
# 3029395  Quito  Pichincha    B        6           NaN      8   31  2017
# 3029396  Quito  Pichincha    B        6           NaN      8   31  2017
# 3029397  Quito  Pichincha    B        6           NaN      8   31  2017
# 3029398  Quito  Pichincha    B        6           NaN      8   31  2017
# 3029399  Quito  Pichincha    B        6           NaN      8   31  2017
#
#          was_holiday
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# 3029395        False
# 3029396        False
# 3029397        False
# 3029398        False
# 3029399        False
#
# [3029400 rows x 18 columns]

# %%
# seperate target features from df to impute oil price

test = impute_df[impute_df['transactions'].isna()]
feature_cols = ['id','city', 'state','dcoilwtico', 'type','store_nbr', 'family',
                 'cluster','month', 'day', 'year', 'transactions']
train = impute_df[~impute_df['transactions'].isna()]
train = train[feature_cols]
test = test[feature_cols]

# %%
# seperate targets and features to impute oil price

X_train = train.drop(['id','transactions'], axis = 1)
y_train = train['transactions']

X_test = test.drop(['id','transactions'], axis = 1)

# %%
# convert strings to catagorical type

categorical_columns = ['city','state','type','family']

for col in categorical_columns:
    X_train[col] = X_train[col].astype('category')
    
for col in categorical_columns:
    X_test[col] = X_test[col].astype('category')

# %%
# create model to predict missing transaction values

cat_features = ['city','state','type','family']

model_data = lgb.Dataset(X_train, label=y_train, categorical_feature = cat_features)


# Set hyperparameters for the model
params = {
    'objective': 'regression',
    'metric': 'mse',
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}

# Train the model
num_round = 100
lgb_model2 = lgb.train(params, model_data, num_round)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026389 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 457
# [LightGBM] [Info] Number of data points in the train set: 2755104, number of used features: 10
# [LightGBM] [Info] Start training from score 1694.602158

# %%
trans_preds = lgb_model2.predict(X_test)

trans_pred_ser = pd.Series(trans_preds)

# %%
trans_pred_ser
# Out:
# 0         1620.242893
# 1         1620.242893
# 2         1620.242893
# 3         1620.242893
# 4         1620.242893
#              ...
# 274291    2028.114435
# 274292    2028.114435
# 274293    2028.114435
# 274294    2028.114435
# 274295    2028.114435
# Length: 274296, dtype: float64

# %%
test['transactions'] = trans_pred_ser.values

# %%
test
# Out:
#               id   city      state  dcoilwtico type  store_nbr  \
# 0              0  Quito  Pichincha   95.162954    D          1
# 1              1  Quito  Pichincha   95.162954    D          1
# 2              2  Quito  Pichincha   95.162954    D          1
# 3              3  Quito  Pichincha   95.162954    D          1
# 4              4  Quito  Pichincha   95.162954    D          1
# ...          ...    ...        ...         ...  ...        ...
# 3029395  3029395  Quito  Pichincha   47.260000    B          9
# 3029396  3029396  Quito  Pichincha   47.260000    B          9
# 3029397  3029397  Quito  Pichincha   47.260000    B          9
# 3029398  3029398  Quito  Pichincha   47.260000    B          9
# 3029399  3029399  Quito  Pichincha   47.260000    B          9
#
#                              family  cluster  month  day  year  transactions
# 0                        AUTOMOTIVE       13      1    1  2013   1620.242893
# 1                         BABY CARE       13      1    1  2013   1620.242893
# 2                            BEAUTY       13      1    1  2013   1620.242893
# 3                         BEVERAGES       13      1    1  2013   1620.242893
# 4                             BOOKS       13      1    1  2013   1620.242893
# ...                             ...      ...    ...  ...   ...           ...
# 3029395                     POULTRY        6      8   31  2017   2028.114435
# 3029396              PREPARED FOODS        6      8   31  2017   2028.114435
# 3029397                     PRODUCE        6      8   31  2017   2028.114435
# 3029398  SCHOOL AND OFFICE SUPPLIES        6      8   31  2017   2028.114435
# 3029399                     SEAFOOD        6      8   31  2017   2028.114435
#
# [274296 rows x 12 columns]

# %%
impute_df.update(test)

# %%
impute_df.isna().sum()
# Out:
# Unnamed: 0          0
# id                  0
# date                0
# store_nbr           0
# family              0
# sales           28512
# onpromotion         0
# data_id             0
# dcoilwtico          0
# city                0
# state               0
# type                0
# cluster             0
# transactions        0
# month               0
# day                 0
# year                0
# was_holiday         0
# dtype: int64

# %%
complete_df = impute_df.copy()

# %%
complete_df
# Out:
#          Unnamed: 0       id        date  store_nbr  \
# 0                 0        0  2013-01-01          1
# 1                 1        1  2013-01-01          1
# 2                 2        2  2013-01-01          1
# 3                 3        3  2013-01-01          1
# 4                 4        4  2013-01-01          1
# ...             ...      ...         ...        ...
# 3029395     3029395  3029395  2017-08-31          9
# 3029396     3029396  3029396  2017-08-31          9
# 3029397     3029397  3029397  2017-08-31          9
# 3029398     3029398  3029398  2017-08-31          9
# 3029399     3029399  3029399  2017-08-31          9
#
#                              family  sales  onpromotion data_id  dcoilwtico  \
# 0                        AUTOMOTIVE    0.0            0     df1   95.162954
# 1                         BABY CARE    0.0            0     df1   95.162954
# 2                            BEAUTY    0.0            0     df1   95.162954
# 3                         BEVERAGES    0.0            0     df1   95.162954
# 4                             BOOKS    0.0            0     df1   95.162954
# ...                             ...    ...          ...     ...         ...
# 3029395                     POULTRY    NaN            1     df2   47.260000
# 3029396              PREPARED FOODS    NaN            0     df2   47.260000
# 3029397                     PRODUCE    NaN            1     df2   47.260000
# 3029398  SCHOOL AND OFFICE SUPPLIES    NaN            9     df2   47.260000
# 3029399                     SEAFOOD    NaN            0     df2   47.260000
#
#           city      state type  cluster  transactions  month  day  year  \
# 0        Quito  Pichincha    D       13   1620.242893      1    1  2013
# 1        Quito  Pichincha    D       13   1620.242893      1    1  2013
# 2        Quito  Pichincha    D       13   1620.242893      1    1  2013
# 3        Quito  Pichincha    D       13   1620.242893      1    1  2013
# 4        Quito  Pichincha    D       13   1620.242893      1    1  2013
# ...        ...        ...  ...      ...           ...    ...  ...   ...
# 3029395  Quito  Pichincha    B        6   2028.114435      8   31  2017
# 3029396  Quito  Pichincha    B        6   2028.114435      8   31  2017
# 3029397  Quito  Pichincha    B        6   2028.114435      8   31  2017
# 3029398  Quito  Pichincha    B        6   2028.114435      8   31  2017
# 3029399  Quito  Pichincha    B        6   2028.114435      8   31  2017
#
#          was_holiday
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# 3029395        False
# 3029396        False
# 3029397        False
# 3029398        False
# 3029399        False
#
# [3029400 rows x 18 columns]

# %%
complete_df.to_csv('cleaned_df.csv')
